# %% [markdown]
# # The title of the final product.
#
# The title for my final product is, "Is NIL Creating a New Era of Inequality in College Football?"

# %% [markdown]
# # 2. An image of the final product.

# %%
![Final Infographic](Infographic/infographic.png)

# %% [markdown]
# # 3. A description of final product.
#
# My final project is about the massive divide in Name, Image, and likeness (NIL) earnings and spending both amoungst the players and confernces themselves.I used a data set that gave accurate evaluations for the top 100 college football players. From this data set, I created a Lorenz curve that was about to show the extreme inequality in NIL earnings. The Lorenz curve showed that a small percentage of players were earning the majority of NIL money, with another graphic showing that the top 4 players made the small as the bottom 60. Although we were only able to look at the top 100, my reserch only lead me to beleive that the ineqaulity just gets wore as you go down the list beyond those players. I also looked at the conference level spending with NIL which proved the pwoer conferences spend over 10 times more on NIL than the smaller conferences. Overall, my final project is meant to show people that the college football landsacape is being completely reshapred by NIL, with the benefits being concentrated in the hands of a few elite players and programs.

# %% [markdown]
# # 4. A Manifest of all resources, i.e. a table of names, brief descriptions, and links to data files, notebooks, and external resources associated with your project
#
# | Resource Name                | Type                              | Description                                                                 | Location / Link                                      |
# |-----------------------------|-----------------------------------|-----------------------------------------------------------------------------|------------------------------------------------------|
# | nil_full_100_combined.csv    | Data file                         | Cleaned data set of top 100 NIL valuations in college football              | Data folder of project                               |
# | infographic.png              | Image file (PNG)                  | This is the final infographic created for my project                        | Infographic/infographic.png                         |
# | ON3 NIL Valuations           | External Data Source (Database)   | This is a site where I found most my data about NIL, it is a sports database| https://www.on3.com/nil/rankings/player/college/football/ |
# | ESPN                         | External Data Source (Database)   | This is a sports data base with public data about players such as players team and their conference | https://www.espn.com/ |
# | Data_Establishment.ipynb     | Notebook                          | Initial Data gathering, cleaing, and structering my new data set            | Notebooks/Data_Exploration.ipynb                    |
# | Data_Exploration.ipynb       | Notebook                          | This is for exploring the data, making preliminary vizualizations, data ransformations, and expiritmaneting with different plots | Notebooks/Data_Final.ipynb |
# | Data_Final.ipynb             | Notebook                          | This is for creating my final infograhich as welll as discplaying and desrcipring the infograpic | Notebooks/Data_Final.ipynb |
# |                             | Coding Resource                   | This is an online resrouce that helped me code the lorenz curve             | https://www.datacamp.com/tutorial/lorenz-curve       |
# | Data camp                    | Coding Resource                   | This is an online resrouce that helped me code the Donut chart              | https://www.datacamp.com/tutorial/tableau-donut-chart |
